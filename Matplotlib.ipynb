# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# %%
fig = plt.plot(x,y,label = '2x',color = 'red',linewidth = 2,marker = '*',markersize = 10,linestyle = '-.')
plt.title('Our first graph', fontdict = {'fontsize':25 , 'fontname': 'Arial'})
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.legend()
# to get integer value for ticks
plt.xticks([0,1,2,3,4])
plt.yticks([0,2,4,6,8,10])
# Out:
# ([<matplotlib.axis.YTick at 0x20620022780>,
# ...
#  <a list of 6 Text major ticklabel objects>)

# %%
# colormarkerline - format strings also called short hand notations (color,marker,line)
plt.plot(x,y,'g+-')

# %%
x = np.arange(0,4.5,0.5)

# %%
plt.figure(figsize = (5,3), dpi = 500) # now the dimensions would be 2500*1500
plt.plot(x,x**2)

# %%
plt.plot(x[:5],x[:5]**2,'r')
plt.plot(x[5:],x[5:]**2,'r--')

# %%
type(x1)
# Out:
# list

# %%
x1[:5]
# Out:
# [0.0, 0.5, 1.0, 1.5, 2.0]

# %%
plt.plot([1,2,3],'r+-')
plt.plot([4,5,6], 'g--')

# %%
x = [4,5,6,7,8,9]

# %%
plt.plot(x1[:4],'r+-')

# %%
x1
# Out:
# [0.0, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0, 3.5, 4.0]

# %%
# to save the figure
plt.savefig('plot.png')

# %%
labels = ['A','B','C']
values = [40,50,60]
fig = plt.bar(labels, values)
fig[0].set_hatch('/')
fig[1].set_hatch('*')
fig[2].set_hatch('+')
plt.show()

# %%
gas= pd.read_excel('gas_prices.xlsx')

# %%
fifa = pd.read_csv('data.csv')

# %%
fifa
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
gas.head()
# Out:
#    Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1  1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2  1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3  1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4  1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
#
#    South Korea    UK   USA
# 0         2.05  2.82  1.16
# 1         2.49  3.01  1.14
# 2         2.65  3.06  1.13
# 3         2.88  2.84  1.11
# 4         2.87  2.99  1.11

# %%
# Out:
# 0     1990
# 3     1993
# 6     1996
# 9     1999
# 12    2002
# 15    2005
# 18    2008
# Name: Year, dtype: int64

# %%
plt.figure(figsize = (5,3),dpi = 100)
plt.plot(gas.Year,gas.USA,'b+-', label = ['USA'])
plt.plot(gas.Year,gas.Canada,'r.-', label = ['Canada'])
plt.plot(gas.Year,gas['South Korea'],'o--',label = ['South Korea'])
plt.xticks(gas.Year[::3]) # keeping all the values in xaxis makes it conjusted
plt.title('Gas price over years',fontdict = {'fontsize':22 , 'fontweight':'bold'})  
plt.legend()

# %%
country = ['Australia', 'Canada', 'France', 'Germany', 'Italy', 'Japan',
       'Mexico', 'South Korea', 'UK', 'USA']

# %%
for entry in country:
    plt.plot(gas.Year,gas[entry])
    #plt.legend()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
for entry in country:
    print(entry)
# Out:
# Australia
# Canada
# France
# Germany
# Italy
# Japan
# Mexico
# South Korea
# UK
# USA

# %%
gas
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1   1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2   1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3   1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4   1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
# 5   1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7   1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
# 8   1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 9   1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79
# 10  2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01
# 11  2001       1.71    1.72    3.51     3.40   3.57   3.27    2.20
# 12  2002       1.76    1.69    3.62     3.67   3.74   3.15    2.24
# ...

# %%
fifa
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
bins = [40,50,60,70,80,90,100]
plt.hist(fifa.Overall,bins = bins,color = 'red')
plt.xticks(bins)
plt.ylabel('Frequency')
plt.xlabel('Overall')
plt.title('Distribution of skill level in fifa')
plt.show()

# %%
x,y =  fifa[fifa['Preferred Foot'] == 'Left'],  fifa[fifa['Preferred Foot'] == 'Right']

# %%
x
# Out:
#        Unnamed: 0      ID                  Name  Age  \
# 0               0  158023              L. Messi   31
# 13             13  168542           David Silva   32
# 15             15  211110             P. Dybala   24
# 17             17  194765          A. Griezmann   27
# 19             19  192119           T. Courtois   26
# ...           ...     ...                   ...  ...
# 18172       18172  243636            C. Hawkins   18
# 18175       18175  243649             E. Clarke   19
# 18191       18191  245570  J. Norville-Williams   18
# 18200       18200  231381              J. Young   18
# 18201       18201  243413              D. Walsh   18
#
#                                                 Photo          Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png            Argentina
# 13     https://cdn.sofifa.org/players/4/19/168542.png                Spain
# 15     https://cdn.sofifa.org/players/4/19/211110.png            Argentina
# ...

# %%
sizes = [len(x),len(y)]
plt.pie(sizes, labels=['left','right'],colors = ['green','blue'],autopct = '%.2f')
# Out:
# ([<matplotlib.patches.Wedge at 0x2062b32e518>,
# ...
#  [Text(0.8207745153900478, 0.7323449971743047, 'left'),
#   Text(-0.8207745496735903, -0.732344958751076, 'right')],
#  [Text(0.4476951902127533, 0.39946090754962066, '23.19'),
#   Text(-0.4476952089128674, -0.3994608865914959, '76.81')])

# %%
fifa.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
fifa['Weight'] = fifa['Weight'].apply(lambda x : x[:-3] if(type(x) == str) else x)

# %%
fifa['Weight']
# Out:
# 0
# 1
# 2
# 3
# 4
#         ..
# 18202
# 18203
# 18204
# 18205
# 18206
# Name: Weight, Length: 18207, dtype: object

# %%
#fifa['Weight'] = pd.to_numeric(fifa['Weight'])

# %%
fifa['Weight']
# Out:
# 0        159
# 1        183
# 2        150
# 3        168
# 4        154
#         ...
# 18202    134
# 18203    170
# 18204    148
# 18205    154
# 18206    176
# Name: Weight, Length: 18207, dtype: object

# %%
dum = pd.read_csv('data.csv')

# %%
dum['Weight'] = dum['Weight'].apply(lambda x : x[:-3] if(type(x) == str) else x)

# %%
dum['Weight'] = pd.to_numeric(dum['Weight'],errors = 'coerce' )

# %%
dum['Weight']
# Out:
# 0        159.0
# 1        183.0
# 2        150.0
# 3        168.0
# 4        154.0
#          ...
# 18202    134.0
# 18203    170.0
# 18204    148.0
# 18205    154.0
# 18206    176.0
# Name: Weight, Length: 18207, dtype: float64

# %%
plt.hist(dum.Weight)
# Out:
# C:\Users\anuj8\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\anuj8\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# (array([4.100e+01, 2.920e+02, 1.998e+03, 6.005e+03, 5.912e+03, 2.484e+03,
#         1.226e+03, 1.820e+02, 1.500e+01, 4.000e+00]),
#  array([110. , 123.3, 136.6, 149.9, 163.2, 176.5, 189.8, 203.1, 216.4,
#         229.7, 243. ]),
#  <a list of 10 Patch objects>)

# %%
light = len(dum.loc[dum['Weight'] < 125])
light_med = len(dum.loc[(dum['Weight'] >=125) & (dum['Weight'] < 150)])
med = len(dum.loc[(dum['Weight'] >=150) & (dum['Weight'] < 175)])
med_heavy = len(dum.loc[(dum['Weight'] >=175) & (dum['Weight'] < 200)])
heavy = len(dum.loc[dum['Weight'] >= 125])

# %%
sizes = [light,light_med,med,med_heavy,heavy]
plt.figure(figsize = (10,10))
explode = (0, 0.1, 0, 0,0.3) 
plt.pie(sizes,labels = ['light','light_med','med','med_heavy','heavy'],autopct='%0.2f %%',explode = explode )
# Out:
# ([<matplotlib.patches.Wedge at 0x2062988d908>,
# ...
#  [Text(1.0999929230318113, 0.003945792687397574, 'light'),
#   Text(1.1742522857114752, 0.24724799190564983, 'light_med'),
#   Text(0.23078601249539243, 1.075517464496266, 'med'),
#   Text(-1.0000164868093564, 0.4582215906190723, 'med_heavy'),
#   Text(-0.02008721204370577, -1.3998558868370383, 'heavy')],
#  [Text(0.5999961398355333, 0.002152250556762313, '0.11 %'),
#   Text(0.6849804999983604, 0.14422799527829572, '6.38 %'),
#   Text(0.12588327954294132, 0.5866458897252359, '30.29 %'),
#   Text(-0.5454635382596489, 0.24993904942858486, '12.76 %'),
#   Text(-0.01291320774238228, -0.8999073558238104, '50.46 %')])

# %%
light
# Out:
# 41

# %%
len(explode)
# Out:
# 4

# %%
barcelona = dum.loc[dum.Club == 'FC Barcelona']['Overall']

# %%
madrid = dum.loc[dum.Club == 'Real Madrid']['Overall']

# %%
plt.boxplot([barcelona,madrid])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2062dbcb6a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2062dbcbda0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2062dbcb550>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x2062cd064e0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x2062cd06860>,
# ...
#  'means': []}

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.arange(40,50)
y = np.arange(10,20)

# %%
a = np.arange(10,15)
b = np.arange(15,20)

# %%
plt.scatter(a,b,c = 'red')

# %%
plt.scatter(x,y,c = 'green')

# %%
plt.subplot(2,2,1)
plt.scatter(x,y,c='r')
plt.subplot(2,2,2)
plt.scatter(a,b,c = 'g')

# %%
x = np.arange(1,11) 
y = 3 * x + 5 
plt.title("Matplotlib demo") 
plt.xlabel("x axis caption") 
plt.ylabel("y axis caption") 
plt.plot(x,y) 
plt.show()

# %%
x = np.arange(0, 4 * np.pi, 0.1) 
y = np.sin(x) 
z = np.cos(x)
plt.title("sine wave form") 
plt.plot(x,y)
plt.plot(x,z)

# %%
#Subplot()
# Compute the x and y coordinates for points on sine and cosine curves 
x = np.arange(0, 5 * np.pi, 0.1) 
y_sin = np.sin(x) 
y_cos = np.cos(x)  
   
# Set up a subplot grid that has height 2 and width 1, 
# and set the first such subplot as active. 
plt.subplot(2, 1, 1)
   
# Make the first plot 
plt.plot(x, y_sin,'r--') 
plt.title('Sine')  
   
# Set the second subplot as active, and make the second plot. 
plt.subplot(2, 1, 2) 
plt.plot(x, y_cos,'g--') 
plt.title('Cosine')  
   
# Show the figure. 
plt.show()

# %%
## Bar plot

x = [2,8,10] 
y = [11,16,9]  

x2 = [3,9,11] 
y2 = [6,15,7] 
plt.bar(x, y) 
plt.bar(x2, y2, color = 'g') 
plt.title('Bar graph') 
plt.ylabel('Y axis') 
plt.xlabel('X axis')  

plt.show()

# %%
np.array([[4,5],[4,6]]).shape
# Out:
# (2, 2)

# %%
bins = [10,20,30]
a = np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27]) 
plt.hist(a,bins = bins) 
plt.title("histogram") 
plt.show()

# %%
data = [np.random.normal(0, std, 100) for std in range(1, 4)]

# %%
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2062e2cce48>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2062e2dd588>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2062e2cccf8>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x2062e2ddc88>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x2062e2e5048>,
# ...
#  'means': []}

# %%
# Data to plot
labels = 'Python', 'C++', 'Ruby', 'Java'
sizes = [215, 130, 245, 210]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.4, 0, 0, 0)  # explode 1st slice

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=False) #autopct is used to insert how percent each pie share is and %% is used for adding a
# percent sign
# Out:
# ([<matplotlib.patches.Wedge at 0x2062e3acd30>,
# ...
#  [Text(0.9963786148748535, 1.1212625276089756, 'Python'),
#   Text(-0.64656382751384, 0.8899186574910392, 'C++'),
#   Text(-0.94900779332915, -0.5562231640272972, 'Ruby'),
#   Text(0.7466808503372186, -0.8077547324155322, 'Java')],
#  [Text(0.664252409916569, 0.747508351739317, '26.9%'),
#   Text(-0.35267117864391273, 0.485410176813294, '16.2%'),
#   Text(-0.5176406145431727, -0.30339445310579843, '30.6%'),
#   Text(0.4072804638203011, -0.44059349040847207, '26.2%')])
